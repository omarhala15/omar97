# %%
#import libraries
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import Image
print('Finsihed loading libraries')
# Out:
# Finsihed loading libraries

# %%
filename='water-treatment1.csv'
df=pd.read_csv(filename,index_col=0)
df.head()
# Out:
#             Q-E  ZN-E  H-E DBO-E DQO-E SS-E SSV-E SED-E  COND-E  PH-P  ...  \
# Date                                                                   ...
# D-1/3/90  44101  1.50  7.8     ?   407  166  66.3   4.5    2110   7.9  ...
# D-2/3/90  39024  3.00  7.7     ?   443  214  69.2   6.5    2660   7.7  ...
# D-4/3/90  32229  5.00  7.6     ?   528  186  69.9   3.4    1666   7.7  ...
# D-5/3/90  35023  3.50  7.9   205   588  192  65.6   4.5    2430   7.8  ...
# D-6/3/90  36924  1.50  8.0   242   496  176  64.8   4.0    2110   7.9  ...
#
#           COND-S  RD-DBO-P RD-SS-P RD-SED-P  RD-DBO-S  RD-DQO-S RD-DBO-G  \
# Date
# D-1/3/90    2000         ?    58.8     95.5         ?      70.0        ?
# D-2/3/90    2590         ?    60.7     94.8         ?      80.8        ?
# D-4/3/90    1888         ?    58.2     95.6         ?      52.9        ?
# D-5/3/90    1840      33.1    64.2     95.3      87.3      72.3     90.2
# ...

# %%
df.shape
# Out:
# (527, 38)

# %%
df.describe()
# Out:
#               H-E       COND-E        PH-P         SS-P       COND-P  \
# count  527.000000   527.000000  527.000000   527.000000   527.000000
# mean     7.810057  1478.620493    7.829981   253.952562  1496.034156
# std      0.246175   394.898019    0.226925   147.458468   402.588656
# min      6.900000   651.000000    7.300000   104.000000   646.000000
# 25%      7.600000  1201.000000    7.700000   184.000000  1217.000000
# 50%      7.800000  1406.000000    7.800000   220.000000  1420.000000
# 75%      8.000000  1672.000000    8.000000   272.000000  1713.500000
# max      8.700000  3230.000000    8.500000  1692.000000  3170.000000
#
#              PH-D       COND-D
# count  527.000000   527.000000
# mean     7.811954  1490.569260
# std      0.199594   399.990816
# min      7.100000    85.000000
# 25%      7.700000  1225.500000
# 50%      7.800000  1428.000000
# 75%      7.900000  1701.000000
# max      8.400000  3690.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 527 entries, D-1/3/90 to D-30/8/91
# Data columns (total 38 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Q-E          527 non-null    object
#  1   ZN-E         527 non-null    object
#  2   H-E          527 non-null    float64
#  3   DBO-E        527 non-null    object
#  4   DQO-E        527 non-null    object
#  5   SS-E         527 non-null    object
#  6   SSV-E        527 non-null    object
#  7   SED-E        527 non-null    object
#  8   COND-E       527 non-null    int64
#  9   PH-P         527 non-null    float64
#  10  DBO-P        527 non-null    object
#  11  SS-P         527 non-null    int64
#  12  SSV-P        527 non-null    object
#  13  SED-P        527 non-null    object
#  14  COND-P       527 non-null    int64
#  15  PH-D         527 non-null    float64
#  16  DBO-D        527 non-null    object
#  17  DQO-D        527 non-null    object
# ...

# %%
df.isnull().sum()
#no null values
# Out:
# Q-E            0
# ZN-E           0
# H-E            0
# DBO-E          0
# DQO-E          0
# SS-E           0
# SSV-E          0
# SED-E          0
# COND-E         0
# PH-P           0
# DBO-P          0
# SS-P           0
# SSV-P          0
# SED-P          0
# COND-P         0
# PH-D           0
# DBO-D          0
# DQO-D          0
# SS-D           0
# SSV-D          0
# SED-D          0
# COND-D         0
# PH-S           0
# DBO-S          0
# DQO-S          0
# SS-S           0
# SSV-S          0
# SED-S          0
#  COND-S        0
# RD-DBO-P       0
# RD-SS-P        0
# RD-SED-P       0
# RD-DBO-S       0
# RD-DQO-S       0
# RD-DBO-G       0
# RD-DQO-G       0
# RD-SS-G        0
#  RD-SED-G      0
# dtype: int64

# %%
unknown_cols=(df=='?').sum()
h_counts=unknown_cols[unknown_cols>0]
h_counts
# Out:
# Q-E            18
# ZN-E            3
# DBO-E          23
# DQO-E           6
# SS-E            1
# SSV-E          11
# SED-E          25
# DBO-P          40
# SSV-P          11
# SED-P          24
# DBO-D          28
# DQO-D           9
# SS-D            2
# SSV-D          13
# SED-D          25
# PH-S            1
# DBO-S          23
# DQO-S          18
# SS-S            5
# SSV-S          17
# SED-S          28
#  COND-S         1
# RD-DBO-P       62
# RD-SS-P         4
# RD-SED-P       27
# RD-DBO-S       40
# RD-DQO-S       26
# RD-DBO-G       36
# RD-DQO-G       25
# RD-SS-G         8
#  RD-SED-G      31
# dtype: int64

# %%
df=pd.DataFrame(df)
df.replace('?', np.NaN, inplace=True)
df
# Out:
#              Q-E  ZN-E  H-E DBO-E DQO-E SS-E SSV-E SED-E  COND-E  PH-P  ...  \
# Date                                                                    ...
# D-1/3/90   44101  1.50  7.8   NaN   407  166  66.3   4.5    2110   7.9  ...
# D-2/3/90   39024  3.00  7.7   NaN   443  214  69.2   6.5    2660   7.7  ...
# D-4/3/90   32229  5.00  7.6   NaN   528  186  69.9   3.4    1666   7.7  ...
# D-5/3/90   35023  3.50  7.9   205   588  192  65.6   4.5    2430   7.8  ...
# D-6/3/90   36924  1.50  8.0   242   496  176  64.8   4.0    2110   7.9  ...
# ...          ...   ...  ...   ...   ...  ...   ...   ...     ...   ...  ...
# D-26/8/91  32723  0.16  7.7    93   252  176  56.8   2.3     894   7.7  ...
# D-27/8/91  33535  0.32  7.8   192   346  172  68.6   4.0     988   7.8  ...
# D-28/8/91  32922  0.30  7.4   139   367  180  64.4   3.0    1060   7.5  ...
# D-29/8/91  32190  0.30  7.3   200   545  258  65.1   4.0    1260   7.4  ...
# ...

# %%
null_cols = []
for i in df.columns:
      if df[i].isnull().sum() !=0:
        null_cols.append(i)

# %%
null_cols
# Out:
# ['Q-E',
#  'ZN-E',
#  'DBO-E',
#  'DQO-E',
#  'SS-E',
#  'SSV-E',
#  'SED-E',
#  'DBO-P',
#  'SSV-P',
#  'SED-P',
#  'DBO-D',
#  'DQO-D',
#  'SS-D',
#  'SSV-D',
#  'SED-D',
#  'PH-S',
#  'DBO-S',
#  'DQO-S',
#  'SS-S',
#  'SSV-S',
#  'SED-S',
#  ' COND-S',
#  'RD-DBO-P',
#  'RD-SS-P',
#  'RD-SED-P',
#  'RD-DBO-S',
#  'RD-DQO-S',
#  'RD-DBO-G',
#  'RD-DQO-G',
#  'RD-SS-G',
#  ' RD-SED-G  ']

# %%
numerical = [x for x in df.columns if df[x].dtype != 'object']
obj = [x for x in df.columns if df[x].dtype == 'object']

# %%
for i in numerical:
    if i in null_cols and df[i].dtype != object:
        df[i]= df[i].fillna(df[i].mean())

# %%
for i in obj:
    if i in null_cols and df[i].dtype == object:
        df[i]= df[i].fillna(df[i].mode()[0])

# %%
df.isnull().sum()
# Out:
df.loc['D-16/7/90':'D-18/7/90','Class']= 'Class 5'
df.loc['D-27/7/90':'D-31/7/90','Class']= 'Class 5'
df.loc['D-6/9/90':'D-13/9/90','Class']= 'Class 5'
df.loc['D-16/9/90':'D-21/9/90','Class']= 'Class 5'
df.loc['D-24/9/90':'D-27/9/90','Class']= 'Class 5'
df.loc['D-1/8/90':'D-7/8/90','Class']= 'Class 5'
df.loc['D-1/10/90':'D-5/10/90','Class']= 'Class 5'
print(len(df[df['Class']=='Class 5']))
#---------------------------------------------------------

df.loc[['D-5/6/90','D-28/5/91','D-31/5/91'],'Class']= 'Class 6'
#-----------------------------------------
df.loc['D-29/4/90','Class']= 'Class 7'
#------------------------------------------
df.loc['D-14/9/90','Class']= 'Class 8'
#------------------------------------------
df.loc[['D-13/8/90', 'D-15/8/90', 'D-19/8/90', 'D-20/8/90', 'D-27/8/90', 'D-1/11/90', 
    'D-4/11/90', 'D-11/11/90', 'D-19/11/90','D-21/10/90', 'D-23/10/90', 'D-26/10/90', 'D-28/10/90', 'D-7/3/91', 'D-24/3/91', 'D-25/3/91',
    'D-1/5/91', 'D-5/5/91', 'D-8/5/91', 'D-9/5/91', 'D-12/5/91', 'D-13/5/91', 'D-26/5/91', 'D-27/5/91',
    'D-26/4/91', 'D-28/4/91', 'D-29/4/91', 'D-2/7/91', 'D-14/7/91', 'D-29/7/91', 'D-9/6/91', 'D-24/6/91',
    'D-1/10/91', 'D-3/10/91', 'D-5/10/91', 'D-12/10/91', 'D-15/10/91', 'D-4/8/91','D-28/8/91', 'D-30/8/91'],'Class']= 'Class 9'
df.loc['D-9/8/91':'D-26/8/91','Class']= 'Class 9'
df.loc['D-12/10/90':'D-17/10/90','Class']= 'Class 9'
df.loc['D-7/10/90':'D-9/10/90','Class']= 'Class 9'
df.loc['D-8/8/90':'D-10/8/90','Class']= 'Class 9'
df.loc['D-12/8/90','Class']= 'Class 10'
df.loc[['D-2/12/90', 'D-4/12/90', 'D-6/12/90','D-21/12/90', 'D-26/12/90',
    'D-15/11/90','D-19/10/90','D-19/3/91', 'D-21/3/91', 'D-22/3/91', 'D-1/2/91', 'D-4/2/91',
    'D-6/2/91', 'D-7/2/91','D-15/2/91', 'D-19/2/91','D-3/1/91', 'D-4/1/91', 'D-7/1/91','D-6/5/91', 'D-4/4/91'],'Class']= 'Class 11'
print(len(df[df['Class']=='Class 9']))
#------------------------------------------------------------------

df.loc['D-10/12/90':'D-14/12/90','Class']= 'Class 11'
df.loc['D-22/11/90':'D-26/11/90','Class']= 'Class 11'
df.loc['D-28/11/90':'D-30/11/90','Class']= 'Class 11'
df.loc['D-13/3/91':'D-15/3/91','Class']= 'Class 11'
df.loc['D-10/2/91':'D-13/2/91','Class']= 'Class 11'
df.loc['D-25/2/91':'D-28/2/91','Class']= 'Class 11'
df.loc['D-21/1/91':'D-24/1/91','Class']= 'Class 11'
df.loc['D-27/1/91':'D-31/1/91','Class']= 'Class 11'
print(len(df[df['Class']=='Class 11']))
#---------------------------------------------------------------

df.loc['D-22/10/90','Class']= 'Class 12'
#-----------------------------------------
df.loc['D-24/5/91','Class']= 'Class 13'
#-----------------------------------------
# Out:
# 275
# 116
# 65
# 53

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 527 entries, D-1/3/90 to D-30/8/91
# Data columns (total 39 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Q-E          527 non-null    object
#  1   ZN-E         527 non-null    object
#  2   H-E          527 non-null    float64
#  3   DBO-E        527 non-null    object
#  4   DQO-E        527 non-null    object
#  5   SS-E         527 non-null    object
#  6   SSV-E        527 non-null    object
#  7   SED-E        527 non-null    object
#  8   COND-E       527 non-null    int64
#  9   PH-P         527 non-null    float64
#  10  DBO-P        527 non-null    object
#  11  SS-P         527 non-null    int64
#  12  SSV-P        527 non-null    object
#  13  SED-P        527 non-null    object
#  14  COND-P       527 non-null    int64
#  15  PH-D         527 non-null    float64
#  16  DBO-D        527 non-null    object
#  17  DQO-D        527 non-null    object
# ...

# %%
for i in obj:
    df[i]=df[i].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 527 entries, D-1/3/90 to D-30/8/91
# Data columns (total 39 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Q-E          527 non-null    float64
#  1   ZN-E         527 non-null    float64
#  2   H-E          527 non-null    float64
#  3   DBO-E        527 non-null    float64
#  4   DQO-E        527 non-null    float64
#  5   SS-E         527 non-null    float64
#  6   SSV-E        527 non-null    float64
#  7   SED-E        527 non-null    float64
#  8   COND-E       527 non-null    int64
#  9   PH-P         527 non-null    float64
#  10  DBO-P        527 non-null    float64
#  11  SS-P         527 non-null    int64
#  12  SSV-P        527 non-null    float64
#  13  SED-P        527 non-null    float64
#  14  COND-P       527 non-null    int64
#  15  PH-D         527 non-null    float64
#  16  DBO-D        527 non-null    float64
#  17  DQO-D        527 non-null    float64
# ...

# %% [markdown]
# # EDA

# %%
df.hist(bins=50,figsize=(20,17))
# Out:
# array([[<AxesSubplot:title={'center':'Q-E'}>,
#         <AxesSubplot:title={'center':'ZN-E'}>,
#         <AxesSubplot:title={'center':'H-E'}>,
#         <AxesSubplot:title={'center':'DBO-E'}>,
#         <AxesSubplot:title={'center':'DQO-E'}>,
#         <AxesSubplot:title={'center':'SS-E'}>],
#        [<AxesSubplot:title={'center':'SSV-E'}>,
#         <AxesSubplot:title={'center':'SED-E'}>,
#         <AxesSubplot:title={'center':'COND-E'}>,
#         <AxesSubplot:title={'center':'PH-P'}>,
#         <AxesSubplot:title={'center':'DBO-P'}>,
#         <AxesSubplot:title={'center':'SS-P'}>],
#        [<AxesSubplot:title={'center':'SSV-P'}>,
#         <AxesSubplot:title={'center':'SED-P'}>,
#         <AxesSubplot:title={'center':'COND-P'}>,
#         <AxesSubplot:title={'center':'PH-D'}>,
#         <AxesSubplot:title={'center':'DBO-D'}>,
#         <AxesSubplot:title={'center':'DQO-D'}>],
#        [<AxesSubplot:title={'center':'SS-D'}>,
#         <AxesSubplot:title={'center':'SSV-D'}>,
# ...

# %%
df.describe()
# Out:
#                 Q-E        ZN-E         H-E       DBO-E       DQO-E  \
# count    527.000000  527.000000  527.000000  527.000000  527.000000
# mean   36960.886148    2.351328    7.810057  186.282732  406.592030
# std     6673.033177    2.743567    0.246175   61.750924  119.708608
# min    10050.000000    0.100000    6.900000   31.000000   81.000000
# 25%    32557.500000    0.900000    7.600000  139.500000  326.500000
# 50%    35729.000000    1.500000    7.800000  179.000000  397.000000
# 75%    41094.000000    3.000000    8.000000  222.000000  474.500000
# max    60081.000000   33.500000    8.700000  438.000000  941.000000
#
#               SS-E       SSV-E       SED-E       COND-E        PH-P  ...  \
# count   527.000000  527.000000  527.000000   527.000000  527.000000  ...
# mean    227.339658   61.503985    4.589374  1478.620493    7.829981  ...
# std     135.832780   12.308208    2.678019   394.898019    0.226925  ...
# ...

# %%
corr=df.corr()

# %%
fig, ax = plt.subplots(figsize=(20, 20))
sns.heatmap(corr, annot=True, cmap="coolwarm", center=0, ax=ax)
# Out:
# <AxesSubplot:>

# %%
df['Class'].value_counts()
# Out:
# Class 1     275
# Class 5     116
# Class 9      65
# Class 11     53
# Class 4       4
# Class 6       3
# Class 2       1
# Class 3       1
# Class 7       1
# Class 8       1
# Class 10      1
# Class 12      1
# Class 13      1
# Name: Class, dtype: int64

# %%
df['Class'].isnull().sum()
# Out:
# 4

# %%
df['Class']= df['Class'].fillna(df['Class'].mode()[0])

# %%
df['Class'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # Random forest classifier

# %%
from sklearn.model_selection import train_test_split
y=df['Class']
X=df.drop('Class',axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train=scaler.transform(X_train)
X_test=scaler.transform(X_test)

# %%
clf = RandomForestClassifier(n_estimators=60, random_state=41)
clf.fit(X_train,y_train)
y_pred=clf.predict(X_test)
accuracy = clf.score(X_test, y_test)
print(y_pred)
print(accuracy)
# Out:
# ['Class 5' 'Class 1' 'Class 1' 'Class 1' 'Class 1' 'Class 1' 'Class 1'
#  'Class 1' 'Class 1' 'Class 1' 'Class 1' 'Class 5' 'Class 5' 'Class 1'
#  'Class 5' 'Class 1' 'Class 1' 'Class 9' 'Class 5' 'Class 1' 'Class 1'
#  'Class 5' 'Class 1' 'Class 1' 'Class 1' 'Class 5' 'Class 9' 'Class 1'
#  'Class 9' 'Class 1' 'Class 1' 'Class 1' 'Class 5' 'Class 1' 'Class 1'
#  'Class 1' 'Class 1' 'Class 5' 'Class 1' 'Class 1' 'Class 5' 'Class 5'
#  'Class 1' 'Class 1' 'Class 9' 'Class 1' 'Class 1' 'Class 1' 'Class 5'
#  'Class 1' 'Class 11' 'Class 1' 'Class 5' 'Class 11' 'Class 1' 'Class 1'
#  'Class 5' 'Class 1' 'Class 1' 'Class 11' 'Class 1' 'Class 1' 'Class 1'
#  'Class 11' 'Class 5' 'Class 1' 'Class 4' 'Class 9' 'Class 1' 'Class 11'
#  'Class 5' 'Class 5' 'Class 1' 'Class 1' 'Class 5' 'Class 1' 'Class 1'
#  'Class 1' 'Class 1' 'Class 5' 'Class 1' 'Class 9' 'Class 1' 'Class 1'
#  'Class 1' 'Class 5' 'Class 5' 'Class 1' 'Class 1' 'Class 5' 'Class 9'
# ...

# %%
# with cross validation
from sklearn.model_selection import cross_val_score
clf1= RandomForestClassifier(n_estimators=100, random_state=123)
scores = cross_val_score(clf1,X_train, y_train, cv=10)
print("Cross-validation scores:", scores)
print("Mean score:", scores.mean())
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=10.
#   warnings.warn(
# Cross-validation scores: [0.69767442 0.76190476 0.80952381 0.88095238 0.71428571 0.76190476
#  0.80952381 0.80952381 0.61904762 0.9047619 ]
# Mean score: 0.7769102990033222

# %%
# using grid search 
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [10, 50,80, 100],
    'max_depth': [2, 5, 10],
    'min_samples_split': [2, 5, 10,15]
}

# Create a random forest classifier
clf3= RandomForestClassifier(random_state=42)

# Create a grid search object with cross-validation
grid_search = GridSearchCV(clf3, param_grid=param_grid, cv=10)

# Fit the grid search object to the training data
grid_search.fit(X_train, y_train)

# Print the best hyperparameters and score
print("Best hyperparameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)

# Evaluate the best model on the test data
best_model = grid_search.best_estimator_
test_score = best_model.score(X_test, y_test)
print("Test score:", test_score)

# %time
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=10.
#   warnings.warn(
# Best hyperparameters: {'max_depth': 10, 'min_samples_split': 5, 'n_estimators': 80}
# Best score: 0.7793466223698782
# Test score: 0.7641509433962265
# Wall time: 0 ns
